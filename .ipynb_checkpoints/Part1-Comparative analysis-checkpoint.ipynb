# %%
import pandas as pd

data = pd.read_excel('MOUSE BRAIN 2DGE PROTEINS /TARASLIA et al TABLE 1.xls')
data = data[['Accession Name','Protein name','Protein MW','pI-Value','Brain part']]
print(data)
# Out:
#     Accession Name                                    Protein name  \
# 0      1433B_MOUSE                      14-3-3 protein beta/alpha
# 1      1433E_MOUSE                         14-3-3 protein epsilon
# 2      1433F_MOUSE                             14-3-3 protein eta
# 3      1433G_MOUSE                           14-3-3 protein gamma
# 4      1433T_MOUSE                           14-3-3 protein theta
# ..             ...                                             ...
# 510     VIME_MOUSE                                       Vimentin
# 511     VINC_MOUSE                                       Vinculin
# 512    VPS29_MOUSE  Vacuolar protein sorting-associated protein 29
# 513     WDR1_MOUSE                  WD repeat-containing protein 1
# 514    WDR61_MOUSE                WD repeat-containing protein 61
#
#      Protein MW  pI-Value                  Brain part
# 0         28183      4.62                  OB, HT, MD
# 1         29326      4.50      OB, MB, HT, HC, CB, MD
# 2         28365      4.66                          OB
# 3         28456      4.70  OB, CC, MB, HT, HC, CB, MD
# 4         28046      4.54                      OB, MD
# ..          ...       ...                         ...
# 510       53712      4.90                          OB
# 511      117215      5.70                  OB, CC, MB
# 512       20654      6.30                  OB, CC, MB
# 513       67049      6.10                      OB, CC
# 514       33923      5.00                          OB
#
# [515 rows x 5 columns]

# %%
OB_data =  data[data['Brain part'].str.contains("OB")  ]
# print(OB_data)

# %%
OB_data
# Out:
#     Accession Name                                    Protein name  \
# 0      1433B_MOUSE                      14-3-3 protein beta/alpha
# 1      1433E_MOUSE                         14-3-3 protein epsilon
# 2      1433F_MOUSE                             14-3-3 protein eta
# 3      1433G_MOUSE                           14-3-3 protein gamma
# 4      1433T_MOUSE                           14-3-3 protein theta
# ..             ...                                             ...
# 510     VIME_MOUSE                                       Vimentin
# 511     VINC_MOUSE                                       Vinculin
# 512    VPS29_MOUSE  Vacuolar protein sorting-associated protein 29
# 513     WDR1_MOUSE                  WD repeat-containing protein 1
# 514    WDR61_MOUSE                WD repeat-containing protein 61
#
#      Protein MW  pI-Value                  Brain part
# 0         28183      4.62                  OB, HT, MD
# 1         29326      4.50      OB, MB, HT, HC, CB, MD
# 2         28365      4.66                          OB
# 3         28456      4.70  OB, CC, MB, HT, HC, CB, MD
# 4         28046      4.54                      OB, MD
# ..          ...       ...                         ...
# 510       53712      4.90                          OB
# 511      117215      5.70                  OB, CC, MB
# 512       20654      6.30                  OB, CC, MB
# 513       67049      6.10                      OB, CC
# 514       33923      5.00                          OB
#
# [348 rows x 5 columns]

# %%
OB_data[OB_data['Brain part']=="OB"  ].shape[0]
print(OB_data)
# Out:
#     Accession Name                                    Protein name  \
# 0      1433B_MOUSE                      14-3-3 protein beta/alpha
# 1      1433E_MOUSE                         14-3-3 protein epsilon
# 2      1433F_MOUSE                             14-3-3 protein eta
# 3      1433G_MOUSE                           14-3-3 protein gamma
# 4      1433T_MOUSE                           14-3-3 protein theta
# ..             ...                                             ...
# 510     VIME_MOUSE                                       Vimentin
# 511     VINC_MOUSE                                       Vinculin
# 512    VPS29_MOUSE  Vacuolar protein sorting-associated protein 29
# 513     WDR1_MOUSE                  WD repeat-containing protein 1
# 514    WDR61_MOUSE                WD repeat-containing protein 61
#
#      Protein MW  pI-Value                  Brain part
# 0         28183      4.62                  OB, HT, MD
# 1         29326      4.50      OB, MB, HT, HC, CB, MD
# 2         28365      4.66                          OB
# 3         28456      4.70  OB, CC, MB, HT, HC, CB, MD
# 4         28046      4.54                      OB, MD
# ..          ...       ...                         ...
# 510       53712      4.90                          OB
# 511      117215      5.70                  OB, CC, MB
# 512       20654      6.30                  OB, CC, MB
# 513       67049      6.10                      OB, CC
# 514       33923      5.00                          OB
#
# [348 rows x 5 columns]

# %%
pd.read_excel('MOUSE BRAIN 2DGE PROTEINS /TARASLIA et al TABLE 2.xls').shape[0]
# Out:
# 55

# %%
OB_data[OB_data['Brain part']=="OB"  ]
# Out:
#     Accession Name                                       Protein name  \
# 2      1433F_MOUSE                                14-3-3 protein eta
# 7      3HIDH_MOUSE  3-hydroxyisobutyrate dehydrogenase, mitochondr...
# 16     ACTBL_MOUSE                         Beta-actin-like protein 2
# 52      ATPO_MOUSE                             ATP synthase subunit O
# 67      CHIP_MOUSE     STIP1 homology and U box-containing protein 1
# 74       CLH_MOUSE                            Clathrin heavy chain 1
# 76     CMPK2_MOUSE                   UMP-CMP kinase 2, mitochondrial
# 80     CNRP1_MOUSE     CB1 cannabinoid receptor-interacting protein 1
# 83      COPD_MOUSE                            Coatomer subunit delta
# 104    DCTN3_MOUSE                                Dynactin subunit 3
# 110     DEST_MOUSE                                            Destrin
# 135     EFTS_MOUSE                               Elongation factor Ts
# 156     FIBB_MOUSE                             Fibrinogen beta chain
# 158    FRIL1_MOUSE                            Ferritin light chain 1
# 159    FRIL2_MOUSE                            Ferritin light chain 2
# 182     GNAO_MOUSE  Guanine nucleotide-binding protein G(o) subuni...
# 194    GSTM5_MOUSE                    Glutathione S-transferase Mu 5
# 199      HBA_MOUSE                          Hemoglobin subunit alpha
# 201     HDGF_MOUSE                    Hepatoma-derived growth factor
# 202    HDGR3_MOUSE   Hepatoma-derived growth factor-related protein 3
# 207    HNRDL_MOUSE  Heterogeneous nuclear ribonucleoprotein D-like...
# 212    HNRPL_MOUSE         Heterogeneous nuclear ribonucleoprotein L
# 227    IF1AX_MOUSE  Eukaryotic translation initiation factor 1A, X...
# 250     KT3K_MOUSE                               Ketosamine-3-kinase
# 310      OMP_MOUSE                          Olfactory marker protein
# 314    PA1B3_MOUSE  Platelet-activating factor acetylhydrolase IB ...
# 317    PCBP1_MOUSE                        Poly(rC)-binding protein 1
# 318    PCBP2_MOUSE                         Poly(rC)-binding protein 2
# 323    PDDC1_MOUSE   Parkinson disease 7 domain-containing protein 1
# 340     PMM2_MOUSE                              Phosphomannomutase 2
# 351    PQBP1_MOUSE                   Polyglutamine-binding protein 1
# 361     PRS8_MOUSE                 26S protease regulatory subunit 8
# 365     PSA4_MOUSE                   Proteasome subunit alpha type-4
# 385     RADI_MOUSE                                            Radixin
# 386     RANG_MOUSE            Ran-specific GTPase-activating protein
# 390     RBM3_MOUSE                    Putative RNA-binding protein 3
# 397      RL4_MOUSE                          60S ribosomal protein L4
# 400     ROA3_MOUSE        Heterogeneous nuclear ribonucleoprotein A3
# 401     ROAA_MOUSE       Heterogeneous nuclear ribonucleoprotein A/B
# 406     SBP1_MOUSE                        Selenium-binding protein 1
# 421    SH3L1_MOUSE  SH3 domain-binding glutamic acid-rich-like pro...
# 422    SH3L2_MOUSE  SH3 domain-binding glutamic acid-rich-like pro...
# 441    STML2_MOUSE                            Stomatin-like protein 2
# 471     TCPH_MOUSE                    T-complex protein 1 subunit eta
# 477     THIM_MOUSE            3-ketoacyl-CoA thiolase, mitochondrial
# 480     THTR_MOUSE                      Thiosulfate sulfurtransferase
# 491    TSNAX_MOUSE                     Translin-associated protein X
# 494     TY3H_MOUSE                          Tyrosine 3-monooxygenase
# 495    U2AF1_MOUSE               Splicing factor U2AF 35 kDa subunit
# 500    UCHL4_MOUSE  Ubiquitin carboxyl-terminal hydrolase isozyme L4
# 510     VIME_MOUSE                                          Vimentin
# 514    WDR61_MOUSE                   WD repeat-containing protein 61
#
#      Protein MW  pI-Value Brain part
# 2         28365      4.66         OB
# 7         35816      9.30         OB
# 16        42319      5.19         OB
# 52        23406     10.50         OB
# 67        35343      5.70         OB
# 74       193202      5.40         OB
# 76        50803      7.10         OB
# 80        18715      8.93         OB
# 83        57637      5.84         OB
# 104       21079      5.80         OB
# 110       18852      9.20         OB
# 135       35711      6.70         OB
# 156       55402      6.83         OB
# 158       20847      5.60         OB
# 159       20887      6.44         OB
# 182       40629      5.23         OB
# 194       27016      7.63         OB
# 199       15133      9.10         OB
# 201       26367      4.70         OB
# 202       22474      9.10         OB
# 207       33709      7.50         OB
# 212       64550      9.10         OB
# 227       16564      4.90         OB
# 250       34646      8.70         OB
# 310       18855      4.80         OB
# 314       25951      6.50         OB
# 317       37987      6.81         OB
# 318       38597      6.37         OB
# 323       23662      6.70         OB
# 340       27981      6.00         OB
# 351       30636      5.80         OB
# 361       45768      7.81         OB
# 365       29737      8.70         OB
# 385       68672      5.78         OB
# 386       23753      5.00         OB
# 390       16595      7.67         OB
# 397       47409     11.70         OB
# 400       39856      9.60         OB
# 401       30926      8.70         OB
# 406       53051      5.90         OB
# 421       12917      4.70         OB
# 422       12361      5.30         OB
# 441       38475      9.53         OB
# 471       60127      8.90         OB
# 477       42288      9.30         OB
# 480       33673      8.80         OB
# 491       33020      6.10         OB
# 494       56357      5.70         OB
# 495       28311     10.10         OB
# 500       26604      4.87         OB
# 510       53712      4.90         OB
# 514       33923      5.00         OB
